# %% [markdown]
# # Exploration
#
# Scratch space for poking at the model. Promote stable code into `src/quickstart/`.
#
# Use the **Python (quickstart)** kernel (registered by `setup.sh`).

# %%
from quickstart import LLMClient
from quickstart.logging import setup_logging

setup_logging()
client = LLMClient()

# %%
from quickstart import LLMClient
client = LLMClient(system="You are a helpful assistant. " * 100)  # long system prompt
reply1 = client.complete("hi", cache_system=True)

# %%
reply2 = client.complete("hi again", cache_system=True)

# %%
reply = client.complete("In one sentence, what is retrieval-augmented generation?")
print(reply)
